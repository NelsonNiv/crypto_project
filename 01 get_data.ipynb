# %%
#agregar directorio de scripts como referencia
import sys
sys.path.append('scripts/')
#importar funciones creadas
import fetch_cmc as fcmc
#importar librerias de sistema
import os

# %%
#descargar
inicio = '2013-01-01'
cierre = '2018-12-25'
fcmc.store_cmc_all(inicio, cierre)
# Out:
# Files to download:2068
# Download Status: BTC_bitcoin downloaded
# Download Status: LTC_litecoin downloaded
# Download Status: NMC_namecoin downloaded
# Download Status: TRC_terracoin downloaded
# Download Status: PPC_peercoin downloaded
# Download Status: NVC_novacoin downloaded
# Download Status: FTC_feathercoin downloaded
# Download Status: MNC_mincoin downloaded
# Download Status: FRC_freicoin downloaded
# Download Status: IXC_ixcoin downloaded
# Download Status: BTB_bitbar downloaded
# Download Status: WDC_worldcoin downloaded
# Download Status: DGC_digitalcoin downloaded
# Download Status: GLD_goldcoin downloaded
# Download Status: ARG_argentum downloaded
# Download Status: FST_fastcoin downloaded
# Download Status: PXC_phoenixcoin downloaded
# Download Status: MEC_megacoin downloaded
# Download Status: IFC_infinitecoin downloaded
# Download Status: XPM_primecoin downloaded
# Download Status: ANC_anoncoin downloaded
# Download Status: CSC_casinocoin downloaded
# ...

# %%
#comprar la cantidad de archivos descargados
array = os.listdir('data/{}/'.format(cierre))
len(array)
# Out:
# 2068
